# %%
import pandas as pd  # Importujemy bibliotekę pandas

# Tworzymy przykładowy DataFrame
data = {
    "Imię": ["Anna", "Jan", "Kasia"],
    "Wiek": [25, 30, 22],
    "Miasto": ["Warszawa", "Kraków", "Gdańsk"]
}

df = pd.DataFrame(data)  # Tworzymy obiekt DataFrame

# Wyświetlamy dane
print(df)
# Out:
#     Imię  Wiek    Miasto
# 0   Anna    25  Warszawa
# 1    Jan    30    Kraków
# 2  Kasia    22    Gdańsk
